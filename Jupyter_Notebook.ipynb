# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## Main hotkeys
#     Ctrl + Enter - выполнение ячейки
#     Shift + Enter - выполнение ячеек и переход на следующую
#     Enter - Переключение в режим редактирования
#     Esc - Выход из режима редактирования
#     Y - Заменить ячейку на Code
#     M - Заменить ячейку на Markdown
#     A - Добавление пустой ячейки сверху
#     B - Добавление пустой ячейки снизу
#     D - Удаления ячейки
#     C - Копирование ячеек
#     X - Вырезание ячеек
#     V - Вставка ячеек

# %% [markdown]
# ## Text formatting
#
# *These are italicized words*
# **These are bold words**
#
# `Highlighted Code`
#
# ***
# Horizontal Lines
# ***
#
# **Lists**
# * This is a bullet list
# * This is a bullet list
#
# 1. This is an ordered list
# 2. This is an ordered list
# ***
#
# &nbsp;Type "nbsp" to add a single space.
# &ensp;Type "ensp" to add 2 spaces.
# &emsp;Type "emsp" to add 4 spaces.
#
# Some text and a <a href="https://" target="_blank">link</a>
# Or [this text with link]()

# %% [markdown]
# ## Working with code

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
2+2
3+3
# Out:
# 4
# 6

# %%
# %%script false
# 2*2
# Out:
# Couldn't find program: 'false'

# %% [markdown]
# ### Example

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 500)
y = np.cumsum(np.random.randn(500, 6), 0)

# %%
plt.figure(figsize=(12, 7))
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %% [markdown]
# ### Additional resources
# 1. reStructuredText --- https://en.wikipedia.org/wiki/ReStructuredText
# 2. LaTeX --- https://linuxhint.com/use-latex-jupyter-notebook/
